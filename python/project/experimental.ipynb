# %%
import pandas as pd
import matplotlib.pyplot as plt
df = pd.read_csv('data/meteorites.csv')
df = df.reset_index()

# %%
df.head()
# Out:
#    index      name   id name_type        class      mass  fall    year  \
# 0      0    Aachen    1     Valid           L5      21.0  Fell  1880.0
# 1      1    Aarhus    2     Valid           H6     720.0  Fell  1951.0
# 2      2      Abee    6     Valid          EH4  107000.0  Fell  1952.0
# 3      3  Acapulco   10     Valid  Acapulcoite    1914.0  Fell  1976.0
# 4      4   Achiras  370     Valid           L6     780.0  Fell  1902.0
#
#         lat       long           geolocation
# 0  50.77500    6.08333     (50.775, 6.08333)
# 1  56.18333   10.23333  (56.18333, 10.23333)
# 2  54.21667 -113.00000    (54.21667, -113.0)
# 3  16.88333  -99.90000     (16.88333, -99.9)
# 4 -33.16667  -64.95000   (-33.16667, -64.95)

# %%
df = df[(df.year.notna()) & (df.year>=1900) & (df.year<=1999) & (df.mass.notna())]

# %%
df.sort_values('year')
# Out:
#        index                         name     id name_type          class  \
# 281      281                    Emmaville  10033     Valid  Eucrite-mmict
# 17330  17330                      Karagai  12255     Valid             L6
# 36049  36049                  Rhine Villa  22594     Valid     Iron, IIIE
# 37721  37721                     Sterling  23723     Valid      Pallasite
# 26        26                Alexandrovsky    465     Valid             H4
# ...      ...                          ...    ...       ...            ...
# 34879  34879  Queen Alexandra Range 99248  21699     Valid            LL5
# 34878  34878  Queen Alexandra Range 99247  21698     Valid             H6
# 34877  34877  Queen Alexandra Range 99246  21697     Valid             H6
# 34953  34953  Queen Alexandra Range 99322  21772     Valid             H6
# 16574  16574        Jiddat al Harasis 016  12104     Valid             H5
#
#          mass   fall    year       lat       long             geolocation
# ...

# %%
print(df)
# Out:
#        index        name     id name_type                 class      mass  \
# 1          1      Aarhus      2     Valid                    H6     720.0
# 2          2        Abee      6     Valid                   EH4  107000.0
# 3          3    Acapulco     10     Valid           Acapulcoite    1914.0
# 4          4     Achiras    370     Valid                    L6     780.0
# 5          5    Adhi Kot    379     Valid                   EH4    4239.0
# ...      ...         ...    ...       ...                   ...       ...
# 45710  45710  Zillah 001  31355     Valid                    L6    1475.0
# 45711  45711  Zillah 002  31356     Valid               Eucrite     172.0
# 45712  45712      Zinder  30409     Valid  Pallasite, ungrouped      46.0
# 45713  45713        Zlin  30410     Valid                    H4       3.3
# 45715  45715  Zulu Queen  30414     Valid                  L3.7     200.0
#
#         fall    year       lat       long             geolocation
# ...

# %%
df2 = df.groupby('year').mass.sum().to_frame()
plt.figure(figsize=(14,6))
plt.yscale('log')
plt.xlabel("Year",  size = 14)
plt.ylabel("Mass", size = 14)
plt.title("Meteorite mass per year", size = 18)
plt.plot(df2)

# %%
print(df.year.min())
print(df.year.max())
# Out:
# 1900.0
# 1999.0

# %%
BigChonksIn1950 = df[(df.year==1950) & (df.mass>50000)]
BigChonksIn1950.head()
# Out:
#        index           name     id name_type        class      mass   fall  \
# 5075    5075   Belle Plaine   5004     Valid           L6   78800.0  Found
# 37798  37798  Tambo Quemado  23797     Valid  Iron, IIIAB  141000.0  Found
#
#          year       lat   long         geolocation
# 5075   1950.0  37.31667 -97.25  (37.31667, -97.25)
# 37798  1950.0 -14.66667 -74.50  (-14.66667, -74.5)

# %%
for index, row in BigChonksIn1950.iterrows():
    print(row.mass)
# Out:
# 78800.0
# 141000.0

# %%
for index, row in df[(df.year==1950) & (df.mass>10000)].iterrows():
    print(row.mass)
# Out:
# 12600.0
# 10800.0
# 10400.0
# 78800.0
# 11300.0
# 27000.0
# 141000.0

# %%
from importlib import reload
plt=reload(plt)

meteoritesIn1940 = []
plotIndex = []
i = 1
for index, row in df[(df.year==1940)].iterrows():
    meteoritesIn1940.append(row.mass)
    plotIndex.append(i)
    i+=1

plt.bar(plotIndex, meteoritesIn1940)
plt.title("meteorites in 1940")
plt.yscale("log")
plt.xlabel("meteorite no.") 
plt.ylabel("mass")
plt.show()

# %%
x = [1,2,3]
y = [1,2,5]
plt.plot(x,y)
plt.show()
